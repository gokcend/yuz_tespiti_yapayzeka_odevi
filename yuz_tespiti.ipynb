# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("test2.jpg")

# %%
plt.imshow(img);

# %%
gray_scale = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray_scale);

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
faces = face_cascade.detectMultiScale(gray_scale, 1.2, 5)

# %%
for (x, y, w, h) in faces:
     (img, (x,y), (x+w, y+h), (0,0,255), 4)
    
cv2.imshow("yuz tespiti", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
def detectFromImage(image):
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
    img = cv2.imread(image)
    gray_scale = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray_scale, 1.2, 1)
    print('Yüz Tespiti:', len(faces))
    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x,y), (x+w, y+h), (0,255,0), 4)
        
    cv2.imshow("baslik", img)
    cv2.waitKey()
    cv2.destroyAllWindows()

# %%
detectFromImage("test2.jpg")
# Out:
# Yüz Tespiti: 11
